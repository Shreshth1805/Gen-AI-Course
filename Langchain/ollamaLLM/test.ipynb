# %%
import os
from dotenv import load_dotenv
load_dotenv()
print(os.getenv("LANGCHAIN_API_KEY"))
print(os.getenv("LANGCHAIN_PROJECT"))
# Out:
# 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
# GenAIAPPWithOPENAI
